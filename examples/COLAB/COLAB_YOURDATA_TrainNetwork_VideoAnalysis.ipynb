# %% [markdown]
# <a href="https://colab.research.google.com/github/AM5820/500-AI-Machine-learning-Deep-learning-Computer-vision-NLP-Projects-with-code/blob/main/examples/COLAB/COLAB_YOURDATA_TrainNetwork_VideoAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepLabCut for your standard (single animal) projects!
#
# Some useful links:
#
# - [DeepLabCut's GitHub: github.com/DeepLabCut/DeepLabCut](https://github.com/DeepLabCut/DeepLabCut)
# - [DeepLabCut's Documentation: User Guide for Single Animal projects](https://deeplabcut.github.io/DeepLabCut/docs/standardDeepLabCut_UserGuide.html)
#
#
# This notebook illustrates how to use the cloud to:
# - create a training set
# - train a network
# - evaluate a network
# - create simple quality check plots
# - analyze novel videos!
#
# ### This notebook assumes you already have a project folder with labeled data!
#
# This notebook demonstrates the necessary steps to use DeepLabCut for your own project.
#
# This shows the most simple code to do so, but many of the functions have additional features, so please check out the overview & the protocol paper!
#
# Nath\*, Mathis\* et al.: Using DeepLabCut for markerless pose estimation during behavior across species. Nature Protocols, 2019.
#
#
# Paper: https://www.nature.com/articles/s41596-019-0176-0
#
# Pre-print: https://www.biorxiv.org/content/biorxiv/early/2018/11/24/476531.full.pdf

# %% [markdown]
# ## First, go to "Runtime" ->"change runtime type"->select "Python3", and then select "GPU"
#
# As the COLAB environments were updated to CUDA 12.X and Python 3.11, we need to install DeepLabCut and TensorFlow in a distinct way to get TensorFlow to connect to the GPU.

# %%
# this will take a couple of minutes to install all the dependencies!
# !pip install --pre deeplabcut

# %% [markdown]
# **(Be sure to click "RESTART RUNTIME" if it is displayed above before moving on !)** You will see this button at the output of the cells above ^.

# %%
import deeplabcut
# Out:
# Loading DLC 3.0.0rc13...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %% [markdown]
# ## Link your Google Drive (with your labeled data, or the demo data):
#
# ### First, place your project folder into you google drive! "i.e. move the folder named "Project-YourName-TheDate" into google drive.

# %%
# Now, let's link to your GoogleDrive. Run this cell and follow the authorization instructions:
# (We recommend putting a copy of the github repo in your google drive if you are using the demo "examples")

from google.colab import drive

drive.mount("/content/drive")

# %%
# !unrar x "/content/Testing_deeplabcut-Ahmed-2026-02-23.rar"

# %% [markdown]
# YOU WILL NEED TO EDIT THE PROJECT PATH **in the config.yaml file** TO BE SET TO YOUR GOOGLE DRIVE LINK!
#
# Typically, this will be: `/content/drive/My Drive/yourProjectFolderName`

# %%
# PLEASE EDIT THIS:
project_folder_name = "Testing_deeplabcut-Ahmed-2026-02-23"
video_type = "mp4" #, mp4, MOV, or avi, whatever you uploaded!

# No need to edit this, we are going to assume you put videos you want to analyze
# in the "videos" folder, but if this is NOT true, edit below:
videofile_path = [f"/content/Testing_deeplabcut-Ahmed-2026-02-23/videos/"]
print(videofile_path)

# The prediction files and labeled videos will be saved in this `labeled-videos` folder
# in your project folder; if you want them elsewhere, you can edit this;
# if you want the output files in the same folder as the videos, set this to an empty string.
destfolder = f"/content/Testing_deeplabcut-Ahmed-2026-02-23/labeled-videos"

#No need to edit this, as you set it when you passed the ProjectFolderName (above):
path_config_file = f"/content/Testing_deeplabcut-Ahmed-2026-02-23/config.yaml"
print(path_config_file)

# This creates a path variable that links to your Google Drive project
# Out:
# ['/content/Testing_deeplabcut-Ahmed-2026-02-23/videos/']
# /content/Testing_deeplabcut-Ahmed-2026-02-23/config.yaml

# %% [markdown]
# ## Create a training dataset:
#
# ### You must do this step inside of Colab
#
# After running this script the training dataset is created and saved in the project directory under the subdirectory **'training-datasets'**
#
# This function also creates new subdirectories under **dlc-models-pytorch** and appends the project config.yaml file with the correct path to the training and testing pose configuration file. These files hold the parameters for training the network. Such an example file is provided with the toolbox and named as **pytorch_config.yaml**.
#
# Now it is the time to start training the network!

# %%
# There are many more functions you can set here, including which network to use!
# Check the docstring for `create_training_dataset` for all options you can use!

deeplabcut.create_training_dataset(
  path_config_file, net_type="resnet_50", engine=deeplabcut.Engine.PYTORCH
)
# Out:
# [(0.95,
#   1,
#   (array([10,  1,  8, 18, 14, 16,  6,  4,  2,  5, 13,  9,  7, 17, 11,  3,  0,
#           15]),
#    array([12])))]

# %% [markdown]
# ## Start training:
# This function trains the network for a specific shuffle of the training dataset.

# %%
# Let's also change the display and save_epochs just in case Colab takes away
# the GPU... If that happens, you can reload from a saved point using the
# `snapshot_path` argument to `deeplabcut.train_network`:
#   deeplabcut.train_network(..., snapshot_path="/content/.../snapshot-050.pt")

# Typically, you want to train to ~200 epochs. We set the batch size to 8 to
# utilize the GPU's capabilities.

# More info and there are more things you can set:
#   https://deeplabcut.github.io/DeepLabCut/docs/standardDeepLabCut_UserGuide.html#g-train-the-network

deeplabcut.train_network(
    path_config_file,
    shuffle=1,
    save_epochs=5,
    epochs=200,
    batch_size=8,
)

# This will run until you stop it (CTRL+C), or hit "STOP" icon, or when it hits the end.
# Out:
# Training with configuration:
# data:
#   bbox_margin: 20
#   colormode: RGB
#   inference:
#     normalize_images: True
#   train:
#     affine:
#       p: 0.5
#       rotation: 30
#       scaling: [0.5, 1.25]
#       translation: 0
#     crop_sampling:
#       width: 448
#       height: 448
#       max_shift: 0.1
#       method: hybrid
#     gaussian_noise: 12.75
#     motion_blur: True
#     normalize_images: True
# device: auto
# inference:
#   multithreading:
#     enabled: True
#     queue_length: 4
#     timeout: 30.0
#   compile:
#     enabled: False
#     backend: inductor
#   autocast:
#     enabled: False
# metadata:
#   project_path: /content/Testing_deeplabcut-Ahmed-2026-02-23
#   pose_config_path: /content/Testing_deeplabcut-Ahmed-2026-02-23/dlc-models-pytorch/iteration-0/Testing_deeplabcutFeb23-trainset95shuffle1/train/pytorch_config.yaml
#   bodyparts: ['left_front_paw', 'right_front_paw', 'left_back_paw', 'right_back_paw', 'left_front_joint', 'right_front_joint', 'left_back_joint', 'right_back_joint', 'objectA']
#   unique_bodyparts: []
#   individuals: ['animal']
#   with_identity: None
# method: bu
# model:
#   backbone:
#     type: ResNet
#     model_name: resnet50_gn
#     output_stride: 16
#     freeze_bn_stats: False
#     freeze_bn_weights: False
#   backbone_output_channels: 2048
#   heads:
#     bodypart:
#       type: HeatmapHead
#       weight_init: normal
#       predictor:
#         type: HeatmapPredictor
#         apply_sigmoid: False
#         clip_scores: True
#         location_refinement: True
#         locref_std: 7.2801
#       target_generator:
#         type: HeatmapGaussianGenerator
#         num_heatmaps: 9
#         pos_dist_thresh: 17
#         heatmap_mode: KEYPOINT
#         gradient_masking: False
#         generate_locref: True
#         locref_std: 7.2801
#       criterion:
#         heatmap:
#           type: WeightedMSECriterion
#           weight: 1.0
#         locref:
#           type: WeightedHuberCriterion
#           weight: 0.05
#       heatmap_config:
#         channels: [2048, 9]
#         kernel_size: [3]
#         strides: [2]
#       locref_config:
#         channels: [2048, 18]
#         kernel_size: [3]
#         strides: [2]
# net_type: resnet_50
# runner:
#   type: PoseTrainingRunner
#   gpus: None
#   key_metric: test.mAP
#   key_metric_asc: True
#   eval_interval: 10
#   optimizer:
#     type: AdamW
#     params:
#       lr: 0.0005
#   scheduler:
#     type: LRListScheduler
#     params:
#       lr_list: [[0.0001], [1e-05]]
#       milestones: [90, 120]
#   snapshots:
#     max_snapshots: 5
#     save_epochs: 5
#     save_optimizer_state: False
# train_settings:
#   batch_size: 8
#   dataloader_workers: 0
#   dataloader_pin_memory: False
#   display_iters: 500
#   epochs: 200
#   seed: 42
# Loading pretrained weights from Hugging Face hub (timm/resnet50_gn.a1h_in1k)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# HTTP Request: HEAD https://huggingface.co/timm/resnet50_gn.a1h_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# HTTP Request: GET https://huggingface.co/api/models/timm/resnet50_gn.a1h_in1k/xet-read-token/b5b1dcfc1a526af275ec440b8d697c66c90a98b1 "HTTP/1.1 200 OK"
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# [timm/resnet50_gn.a1h_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Data Transforms:
#   Training:   Compose([
#   Affine(always_apply=False, p=0.5, interpolation=1, mask_interpolation=0, cval=0, mode=0, scale={'x': (0.5, 1.25), 'y': (0.5, 1.25)}, translate_percent=None, translate_px={'x': (0, 0), 'y': (0, 0)}, rotate=(-30, 30), fit_output=False, shear={'x': (0.0, 0.0), 'y': (0.0, 0.0)}, cval_mask=0, keep_ratio=True, rotate_method='largest_box'),
#   PadIfNeeded(always_apply=True, p=1.0, min_height=448, min_width=448, pad_height_divisor=None, pad_width_divisor=None, position=PositionType.CENTER, border_mode=0, value=None, mask_value=None),
#   KeypointAwareCrop(always_apply=True, p=1.0, width=448, height=448, max_shift=0.1, crop_sampling='hybrid'),
#   MotionBlur(always_apply=False, p=0.5, blur_limit=(3, 7), allow_shifted=True),
#   GaussNoise(always_apply=False, p=0.5, var_limit=(0, 162.5625), per_channel=True, mean=0),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
# ], p=1.0, bbox_params={'format': 'coco', 'label_fields': ['bbox_labels'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True}, keypoint_params={'format': 'xy', 'label_fields': ['class_labels'], 'remove_invisible': False, 'angle_in_degrees': True, 'check_each_transform': True}, additional_targets={}, is_check_shapes=True)
#   Validation: Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
# ], p=1.0, bbox_params={'format': 'coco', 'label_fields': ['bbox_labels'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True}, keypoint_params={'format': 'xy', 'label_fields': ['class_labels'], 'remove_invisible': False, 'angle_in_degrees': True, 'check_each_transform': True}, additional_targets={}, is_check_shapes=True)
# Using 18 images and 1 for testing
#
# Starting pose model training...
# --------------------------------------------------
# Epoch 1/200 (lr=0.0005), train loss 0.01764, GPU: 7774.0/14912.7 MiB
# Epoch 2/200 (lr=0.0005), train loss 0.01532, GPU: 7774.0/14912.7 MiB
# Epoch 3/200 (lr=0.0005), train loss 0.01539, GPU: 7774.0/14912.7 MiB
# Epoch 4/200 (lr=0.0005), train loss 0.01500, GPU: 7774.0/14912.7 MiB
# Epoch 5/200 (lr=0.0005), train loss 0.01424, GPU: 7774.0/14912.7 MiB
# Epoch 6/200 (lr=0.0005), train loss 0.01270, GPU: 7774.0/14912.7 MiB
# Epoch 7/200 (lr=0.0005), train loss 0.01165, GPU: 7774.0/14912.7 MiB
# Epoch 8/200 (lr=0.0005), train loss 0.01082, GPU: 7774.0/14912.7 MiB
# Epoch 9/200 (lr=0.0005), train loss 0.00973, GPU: 7774.0/14912.7 MiB
# Training for epoch 10 done, starting evaluation
# Epoch 10/200 (lr=0.0005), train loss 0.00919, valid loss 0.01179, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          52.64
#   metrics/test.rmse_pcutoff:  66.40
#   metrics/test.mAP:            0.00
#   metrics/test.mAR:            0.00
# Epoch 11/200 (lr=0.0005), train loss 0.00923, GPU: 7774.0/14912.7 MiB
# Epoch 12/200 (lr=0.0005), train loss 0.00947, GPU: 7774.0/14912.7 MiB
# Epoch 13/200 (lr=0.0005), train loss 0.00869, GPU: 7774.0/14912.7 MiB
# Epoch 14/200 (lr=0.0005), train loss 0.00709, GPU: 7774.0/14912.7 MiB
# Epoch 15/200 (lr=0.0005), train loss 0.00679, GPU: 7774.0/14912.7 MiB
# Epoch 16/200 (lr=0.0005), train loss 0.00680, GPU: 7774.0/14912.7 MiB
# Epoch 17/200 (lr=0.0005), train loss 0.00651, GPU: 7774.0/14912.7 MiB
# Epoch 18/200 (lr=0.0005), train loss 0.00599, GPU: 7774.0/14912.7 MiB
# Epoch 19/200 (lr=0.0005), train loss 0.00646, GPU: 7774.0/14912.7 MiB
# Training for epoch 20 done, starting evaluation
# Epoch 20/200 (lr=0.0005), train loss 0.00605, valid loss 0.00669, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          22.48
#   metrics/test.rmse_pcutoff:    nan
#   metrics/test.mAP:           10.00
#   metrics/test.mAR:           10.00
# Epoch 21/200 (lr=0.0005), train loss 0.00571, GPU: 7774.0/14912.7 MiB
# Epoch 22/200 (lr=0.0005), train loss 0.00508, GPU: 7774.0/14912.7 MiB
# Epoch 23/200 (lr=0.0005), train loss 0.00474, GPU: 7774.0/14912.7 MiB
# Epoch 24/200 (lr=0.0005), train loss 0.00556, GPU: 7774.0/14912.7 MiB
# Epoch 25/200 (lr=0.0005), train loss 0.00521, GPU: 7774.0/14912.7 MiB
# Epoch 26/200 (lr=0.0005), train loss 0.00471, GPU: 7774.0/14912.7 MiB
# Epoch 27/200 (lr=0.0005), train loss 0.00466, GPU: 7774.0/14912.7 MiB
# Epoch 28/200 (lr=0.0005), train loss 0.00407, GPU: 7774.0/14912.7 MiB
# Epoch 29/200 (lr=0.0005), train loss 0.00522, GPU: 7774.0/14912.7 MiB
# Training for epoch 30 done, starting evaluation
# Epoch 30/200 (lr=0.0005), train loss 0.00420, valid loss 0.00664, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          14.58
#   metrics/test.rmse_pcutoff:   9.00
#   metrics/test.mAP:           30.00
#   metrics/test.mAR:           30.00
# Epoch 31/200 (lr=0.0005), train loss 0.00403, GPU: 7774.0/14912.7 MiB
# Epoch 32/200 (lr=0.0005), train loss 0.00386, GPU: 7774.0/14912.7 MiB
# Epoch 33/200 (lr=0.0005), train loss 0.00454, GPU: 7774.0/14912.7 MiB
# Epoch 34/200 (lr=0.0005), train loss 0.00325, GPU: 7774.0/14912.7 MiB
# Epoch 35/200 (lr=0.0005), train loss 0.00332, GPU: 7774.0/14912.7 MiB
# Epoch 36/200 (lr=0.0005), train loss 0.00314, GPU: 7774.0/14912.7 MiB
# Epoch 37/200 (lr=0.0005), train loss 0.00319, GPU: 7774.0/14912.7 MiB
# Epoch 38/200 (lr=0.0005), train loss 0.00358, GPU: 7774.0/14912.7 MiB
# Epoch 39/200 (lr=0.0005), train loss 0.00270, GPU: 7774.0/14912.7 MiB
# Training for epoch 40 done, starting evaluation
# Epoch 40/200 (lr=0.0005), train loss 0.00287, valid loss 0.00589, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          12.94
#   metrics/test.rmse_pcutoff:   5.19
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 41/200 (lr=0.0005), train loss 0.00248, GPU: 7774.0/14912.7 MiB
# Epoch 42/200 (lr=0.0005), train loss 0.00292, GPU: 7774.0/14912.7 MiB
# Epoch 43/200 (lr=0.0005), train loss 0.00285, GPU: 7774.0/14912.7 MiB
# Epoch 44/200 (lr=0.0005), train loss 0.00340, GPU: 7774.0/14912.7 MiB
# Epoch 45/200 (lr=0.0005), train loss 0.00306, GPU: 7774.0/14912.7 MiB
# Epoch 46/200 (lr=0.0005), train loss 0.00322, GPU: 7774.0/14912.7 MiB
# Epoch 47/200 (lr=0.0005), train loss 0.00346, GPU: 7774.0/14912.7 MiB
# Epoch 48/200 (lr=0.0005), train loss 0.00313, GPU: 7774.0/14912.7 MiB
# Epoch 49/200 (lr=0.0005), train loss 0.00294, GPU: 7774.0/14912.7 MiB
# Training for epoch 50 done, starting evaluation
# Epoch 50/200 (lr=0.0005), train loss 0.00274, valid loss 0.00641, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          10.80
#   metrics/test.rmse_pcutoff:   6.53
#   metrics/test.mAP:           50.00
#   metrics/test.mAR:           50.00
# Epoch 51/200 (lr=0.0005), train loss 0.00270, GPU: 7774.0/14912.7 MiB
# Epoch 52/200 (lr=0.0005), train loss 0.00266, GPU: 7774.0/14912.7 MiB
# Epoch 53/200 (lr=0.0005), train loss 0.00209, GPU: 7774.0/14912.7 MiB
# Epoch 54/200 (lr=0.0005), train loss 0.00217, GPU: 7774.0/14912.7 MiB
# Epoch 55/200 (lr=0.0005), train loss 0.00273, GPU: 7774.0/14912.7 MiB
# Epoch 56/200 (lr=0.0005), train loss 0.00237, GPU: 7774.0/14912.7 MiB
# Epoch 57/200 (lr=0.0005), train loss 0.00235, GPU: 7774.0/14912.7 MiB
# Epoch 58/200 (lr=0.0005), train loss 0.00209, GPU: 7774.0/14912.7 MiB
# Epoch 59/200 (lr=0.0005), train loss 0.00208, GPU: 7774.0/14912.7 MiB
# Training for epoch 60 done, starting evaluation
# Epoch 60/200 (lr=0.0005), train loss 0.00291, valid loss 0.00546, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          12.84
#   metrics/test.rmse_pcutoff:   3.71
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 61/200 (lr=0.0005), train loss 0.00295, GPU: 7774.0/14912.7 MiB
# Epoch 62/200 (lr=0.0005), train loss 0.00251, GPU: 7774.0/14912.7 MiB
# Epoch 63/200 (lr=0.0005), train loss 0.00258, GPU: 7774.0/14912.7 MiB
# Epoch 64/200 (lr=0.0005), train loss 0.00188, GPU: 7774.0/14912.7 MiB
# Epoch 65/200 (lr=0.0005), train loss 0.00225, GPU: 7774.0/14912.7 MiB
# Epoch 66/200 (lr=0.0005), train loss 0.00235, GPU: 7774.0/14912.7 MiB
# Epoch 67/200 (lr=0.0005), train loss 0.00206, GPU: 7774.0/14912.7 MiB
# Epoch 68/200 (lr=0.0005), train loss 0.00240, GPU: 7774.0/14912.7 MiB
# Epoch 69/200 (lr=0.0005), train loss 0.00252, GPU: 7774.0/14912.7 MiB
# Training for epoch 70 done, starting evaluation
# Epoch 70/200 (lr=0.0005), train loss 0.00223, valid loss 0.00668, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          14.42
#   metrics/test.rmse_pcutoff:  23.84
#   metrics/test.mAP:           30.00
#   metrics/test.mAR:           30.00
# Epoch 71/200 (lr=0.0005), train loss 0.00242, GPU: 7774.0/14912.7 MiB
# Epoch 72/200 (lr=0.0005), train loss 0.00232, GPU: 7774.0/14912.7 MiB
# Epoch 73/200 (lr=0.0005), train loss 0.00284, GPU: 7774.0/14912.7 MiB
# Epoch 74/200 (lr=0.0005), train loss 0.00202, GPU: 7774.0/14912.7 MiB
# Epoch 75/200 (lr=0.0005), train loss 0.00180, GPU: 7774.0/14912.7 MiB
# Epoch 76/200 (lr=0.0005), train loss 0.00213, GPU: 7774.0/14912.7 MiB
# Epoch 77/200 (lr=0.0005), train loss 0.00204, GPU: 7774.0/14912.7 MiB
# Epoch 78/200 (lr=0.0005), train loss 0.00217, GPU: 7774.0/14912.7 MiB
# Epoch 79/200 (lr=0.0005), train loss 0.00179, GPU: 7774.0/14912.7 MiB
# Training for epoch 80 done, starting evaluation
# Epoch 80/200 (lr=0.0005), train loss 0.00233, valid loss 0.00614, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          13.45
#   metrics/test.rmse_pcutoff:   4.50
#   metrics/test.mAP:           30.00
#   metrics/test.mAR:           30.00
# Epoch 81/200 (lr=0.0005), train loss 0.00288, GPU: 7774.0/14912.7 MiB
# Epoch 82/200 (lr=0.0005), train loss 0.00270, GPU: 7774.0/14912.7 MiB
# Epoch 83/200 (lr=0.0005), train loss 0.00227, GPU: 7774.0/14912.7 MiB
# Epoch 84/200 (lr=0.0005), train loss 0.00180, GPU: 7774.0/14912.7 MiB
# Epoch 85/200 (lr=0.0005), train loss 0.00243, GPU: 7774.0/14912.7 MiB
# Epoch 86/200 (lr=0.0005), train loss 0.00191, GPU: 7774.0/14912.7 MiB
# Epoch 87/200 (lr=0.0005), train loss 0.00213, GPU: 7774.0/14912.7 MiB
# Epoch 88/200 (lr=0.0005), train loss 0.00234, GPU: 7774.0/14912.7 MiB
# Epoch 89/200 (lr=0.0005), train loss 0.00186, GPU: 7774.0/14912.7 MiB
# Training for epoch 90 done, starting evaluation
# Epoch 90/200 (lr=0.0001), train loss 0.00200, valid loss 0.00537, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:           8.60
#   metrics/test.rmse_pcutoff:   8.73
#   metrics/test.mAP:           60.00
#   metrics/test.mAR:           60.00
# Epoch 91/200 (lr=0.0001), train loss 0.00224, GPU: 7774.0/14912.7 MiB
# Epoch 92/200 (lr=0.0001), train loss 0.00131, GPU: 7774.0/14912.7 MiB
# Epoch 93/200 (lr=0.0001), train loss 0.00175, GPU: 7774.0/14912.7 MiB
# Epoch 94/200 (lr=0.0001), train loss 0.00159, GPU: 7774.0/14912.7 MiB
# Epoch 95/200 (lr=0.0001), train loss 0.00166, GPU: 7774.0/14912.7 MiB
# Epoch 96/200 (lr=0.0001), train loss 0.00143, GPU: 7774.0/14912.7 MiB
# Epoch 97/200 (lr=0.0001), train loss 0.00138, GPU: 7774.0/14912.7 MiB
# Epoch 98/200 (lr=0.0001), train loss 0.00129, GPU: 7774.0/14912.7 MiB
# Epoch 99/200 (lr=0.0001), train loss 0.00196, GPU: 7774.0/14912.7 MiB
# Training for epoch 100 done, starting evaluation
# Epoch 100/200 (lr=0.0001), train loss 0.00134, valid loss 0.00563, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          13.28
#   metrics/test.rmse_pcutoff:   5.04
#   metrics/test.mAP:           30.00
#   metrics/test.mAR:           30.00
# Epoch 101/200 (lr=0.0001), train loss 0.00126, GPU: 7774.0/14912.7 MiB
# Epoch 102/200 (lr=0.0001), train loss 0.00121, GPU: 7774.0/14912.7 MiB
# Epoch 103/200 (lr=0.0001), train loss 0.00145, GPU: 7774.0/14912.7 MiB
# Epoch 104/200 (lr=0.0001), train loss 0.00111, GPU: 7774.0/14912.7 MiB
# Epoch 105/200 (lr=0.0001), train loss 0.00159, GPU: 7774.0/14912.7 MiB
# Epoch 106/200 (lr=0.0001), train loss 0.00096, GPU: 7774.0/14912.7 MiB
# Epoch 107/200 (lr=0.0001), train loss 0.00167, GPU: 7774.0/14912.7 MiB
# Epoch 108/200 (lr=0.0001), train loss 0.00127, GPU: 7774.0/14912.7 MiB
# Epoch 109/200 (lr=0.0001), train loss 0.00146, GPU: 7774.0/14912.7 MiB
# Training for epoch 110 done, starting evaluation
# Epoch 110/200 (lr=0.0001), train loss 0.00093, valid loss 0.00540, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          13.00
#   metrics/test.rmse_pcutoff:   7.17
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 111/200 (lr=0.0001), train loss 0.00102, GPU: 7774.0/14912.7 MiB
# Epoch 112/200 (lr=0.0001), train loss 0.00109, GPU: 7774.0/14912.7 MiB
# Epoch 113/200 (lr=0.0001), train loss 0.00126, GPU: 7774.0/14912.7 MiB
# Epoch 114/200 (lr=0.0001), train loss 0.00142, GPU: 7774.0/14912.7 MiB
# Epoch 115/200 (lr=0.0001), train loss 0.00115, GPU: 7774.0/14912.7 MiB
# Epoch 116/200 (lr=0.0001), train loss 0.00105, GPU: 7774.0/14912.7 MiB
# Epoch 117/200 (lr=0.0001), train loss 0.00105, GPU: 7774.0/14912.7 MiB
# Epoch 118/200 (lr=0.0001), train loss 0.00097, GPU: 7774.0/14912.7 MiB
# Epoch 119/200 (lr=0.0001), train loss 0.00098, GPU: 7774.0/14912.7 MiB
# Training for epoch 120 done, starting evaluation
# Epoch 120/200 (lr=1e-05), train loss 0.00113, valid loss 0.00562, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          13.23
#   metrics/test.rmse_pcutoff:   5.56
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 121/200 (lr=1e-05), train loss 0.00120, GPU: 7774.0/14912.7 MiB
# Epoch 122/200 (lr=1e-05), train loss 0.00142, GPU: 7774.0/14912.7 MiB
# Epoch 123/200 (lr=1e-05), train loss 0.00148, GPU: 7774.0/14912.7 MiB
# Epoch 124/200 (lr=1e-05), train loss 0.00109, GPU: 7774.0/14912.7 MiB
# Epoch 125/200 (lr=1e-05), train loss 0.00099, GPU: 7774.0/14912.7 MiB
# Epoch 126/200 (lr=1e-05), train loss 0.00111, GPU: 7774.0/14912.7 MiB
# Epoch 127/200 (lr=1e-05), train loss 0.00117, GPU: 7774.0/14912.7 MiB
# Epoch 128/200 (lr=1e-05), train loss 0.00098, GPU: 7774.0/14912.7 MiB
# Epoch 129/200 (lr=1e-05), train loss 0.00234, GPU: 7774.0/14912.7 MiB
# Training for epoch 130 done, starting evaluation
# Epoch 130/200 (lr=1e-05), train loss 0.00176, valid loss 0.00554, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          13.04
#   metrics/test.rmse_pcutoff:   4.93
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 131/200 (lr=1e-05), train loss 0.00109, GPU: 7774.0/14912.7 MiB
# Epoch 132/200 (lr=1e-05), train loss 0.00100, GPU: 7774.0/14912.7 MiB
# Epoch 133/200 (lr=1e-05), train loss 0.00124, GPU: 7774.0/14912.7 MiB
# Epoch 134/200 (lr=1e-05), train loss 0.00097, GPU: 7774.0/14912.7 MiB
# Epoch 135/200 (lr=1e-05), train loss 0.00110, GPU: 7774.0/14912.7 MiB
# Epoch 136/200 (lr=1e-05), train loss 0.00135, GPU: 7774.0/14912.7 MiB
# Epoch 137/200 (lr=1e-05), train loss 0.00142, GPU: 7774.0/14912.7 MiB
# Epoch 138/200 (lr=1e-05), train loss 0.00104, GPU: 7774.0/14912.7 MiB
# Epoch 139/200 (lr=1e-05), train loss 0.00084, GPU: 7774.0/14912.7 MiB
# Training for epoch 140 done, starting evaluation
# Epoch 140/200 (lr=1e-05), train loss 0.00107, valid loss 0.00548, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          13.10
#   metrics/test.rmse_pcutoff:   4.91
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 141/200 (lr=1e-05), train loss 0.00144, GPU: 7774.0/14912.7 MiB
# Epoch 142/200 (lr=1e-05), train loss 0.00094, GPU: 7774.0/14912.7 MiB
# Epoch 143/200 (lr=1e-05), train loss 0.00111, GPU: 7774.0/14912.7 MiB
# Epoch 144/200 (lr=1e-05), train loss 0.00113, GPU: 7774.0/14912.7 MiB
# Epoch 145/200 (lr=1e-05), train loss 0.00110, GPU: 7774.0/14912.7 MiB
# Epoch 146/200 (lr=1e-05), train loss 0.00132, GPU: 7774.0/14912.7 MiB
# Epoch 147/200 (lr=1e-05), train loss 0.00105, GPU: 7774.0/14912.7 MiB
# Epoch 148/200 (lr=1e-05), train loss 0.00106, GPU: 7774.0/14912.7 MiB
# Epoch 149/200 (lr=1e-05), train loss 0.00107, GPU: 7774.0/14912.7 MiB
# Training for epoch 150 done, starting evaluation
# Epoch 150/200 (lr=1e-05), train loss 0.00141, valid loss 0.00537, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          12.81
#   metrics/test.rmse_pcutoff:   4.74
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 151/200 (lr=1e-05), train loss 0.00134, GPU: 7774.0/14912.7 MiB
# Epoch 152/200 (lr=1e-05), train loss 0.00156, GPU: 7774.0/14912.7 MiB
# Epoch 153/200 (lr=1e-05), train loss 0.00142, GPU: 7774.0/14912.7 MiB
# Epoch 154/200 (lr=1e-05), train loss 0.00118, GPU: 7774.0/14912.7 MiB
# Epoch 155/200 (lr=1e-05), train loss 0.00102, GPU: 7774.0/14912.7 MiB
# Epoch 156/200 (lr=1e-05), train loss 0.00188, GPU: 7774.0/14912.7 MiB
# Epoch 157/200 (lr=1e-05), train loss 0.00103, GPU: 7774.0/14912.7 MiB
# Epoch 158/200 (lr=1e-05), train loss 0.00131, GPU: 7774.0/14912.7 MiB
# Epoch 159/200 (lr=1e-05), train loss 0.00094, GPU: 7774.0/14912.7 MiB
# Training for epoch 160 done, starting evaluation
# Epoch 160/200 (lr=1e-05), train loss 0.00128, valid loss 0.00542, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          12.79
#   metrics/test.rmse_pcutoff:   7.26
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 161/200 (lr=1e-05), train loss 0.00109, GPU: 7774.0/14912.7 MiB
# Epoch 162/200 (lr=1e-05), train loss 0.00112, GPU: 7774.0/14912.7 MiB
# Epoch 163/200 (lr=1e-05), train loss 0.00121, GPU: 7774.0/14912.7 MiB
# Epoch 164/200 (lr=1e-05), train loss 0.00131, GPU: 7774.0/14912.7 MiB
# Epoch 165/200 (lr=1e-05), train loss 0.00130, GPU: 7774.0/14912.7 MiB
# Epoch 166/200 (lr=1e-05), train loss 0.00111, GPU: 7774.0/14912.7 MiB
# Epoch 167/200 (lr=1e-05), train loss 0.00141, GPU: 7774.0/14912.7 MiB
# Epoch 168/200 (lr=1e-05), train loss 0.00133, GPU: 7774.0/14912.7 MiB
# Epoch 169/200 (lr=1e-05), train loss 0.00146, GPU: 7774.0/14912.7 MiB
# Training for epoch 170 done, starting evaluation
# Epoch 170/200 (lr=1e-05), train loss 0.00086, valid loss 0.00542, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          12.98
#   metrics/test.rmse_pcutoff:   6.90
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 171/200 (lr=1e-05), train loss 0.00132, GPU: 7774.0/14912.7 MiB
# Epoch 172/200 (lr=1e-05), train loss 0.00121, GPU: 7774.0/14912.7 MiB
# Epoch 173/200 (lr=1e-05), train loss 0.00119, GPU: 7774.0/14912.7 MiB
# Epoch 174/200 (lr=1e-05), train loss 0.00084, GPU: 7774.0/14912.7 MiB
# Epoch 175/200 (lr=1e-05), train loss 0.00136, GPU: 7774.0/14912.7 MiB
# Epoch 176/200 (lr=1e-05), train loss 0.00091, GPU: 7774.0/14912.7 MiB
# Epoch 177/200 (lr=1e-05), train loss 0.00104, GPU: 7774.0/14912.7 MiB
# Epoch 178/200 (lr=1e-05), train loss 0.00166, GPU: 7774.0/14912.7 MiB
# Epoch 179/200 (lr=1e-05), train loss 0.00127, GPU: 7774.0/14912.7 MiB
# Training for epoch 180 done, starting evaluation
# Epoch 180/200 (lr=1e-05), train loss 0.00191, valid loss 0.00545, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:          13.00
#   metrics/test.rmse_pcutoff:   7.02
#   metrics/test.mAP:           40.00
#   metrics/test.mAR:           40.00
# Epoch 181/200 (lr=1e-05), train loss 0.00088, GPU: 7774.0/14912.7 MiB
# Epoch 182/200 (lr=1e-05), train loss 0.00117, GPU: 7774.0/14912.7 MiB
# Epoch 183/200 (lr=1e-05), train loss 0.00101, GPU: 7774.0/14912.7 MiB
# Epoch 184/200 (lr=1e-05), train loss 0.00108, GPU: 7774.0/14912.7 MiB
# Epoch 185/200 (lr=1e-05), train loss 0.00088, GPU: 7774.0/14912.7 MiB
# Epoch 186/200 (lr=1e-05), train loss 0.00148, GPU: 7774.0/14912.7 MiB
# Epoch 187/200 (lr=1e-05), train loss 0.00090, GPU: 7774.0/14912.7 MiB
# Epoch 188/200 (lr=1e-05), train loss 0.00105, GPU: 7774.0/14912.7 MiB
# Epoch 189/200 (lr=1e-05), train loss 0.00092, GPU: 7774.0/14912.7 MiB
# Training for epoch 190 done, starting evaluation
# Epoch 190/200 (lr=1e-05), train loss 0.00083, valid loss 0.00540, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:           8.19
#   metrics/test.rmse_pcutoff:   6.83
#   metrics/test.mAP:           60.00
#   metrics/test.mAR:           60.00
# Epoch 191/200 (lr=1e-05), train loss 0.00094, GPU: 7774.0/14912.7 MiB
# Epoch 192/200 (lr=1e-05), train loss 0.00109, GPU: 7774.0/14912.7 MiB
# Epoch 193/200 (lr=1e-05), train loss 0.00126, GPU: 7774.0/14912.7 MiB
# Epoch 194/200 (lr=1e-05), train loss 0.00087, GPU: 7774.0/14912.7 MiB
# Epoch 195/200 (lr=1e-05), train loss 0.00099, GPU: 7774.0/14912.7 MiB
# Epoch 196/200 (lr=1e-05), train loss 0.00125, GPU: 7774.0/14912.7 MiB
# Epoch 197/200 (lr=1e-05), train loss 0.00116, GPU: 7774.0/14912.7 MiB
# Epoch 198/200 (lr=1e-05), train loss 0.00147, GPU: 7774.0/14912.7 MiB
# Epoch 199/200 (lr=1e-05), train loss 0.00088, GPU: 7774.0/14912.7 MiB
# Training for epoch 200 done, starting evaluation
# Epoch 200/200 (lr=1e-05), train loss 0.00094, valid loss 0.00542, GPU: 7774.0/14912.7 MiB
# Model performance:
#   metrics/test.rmse:           8.02
#   metrics/test.rmse_pcutoff:   6.89
#   metrics/test.mAP:           60.00
#   metrics/test.mAR:           60.00

# %% [markdown]
# Note, that **when you hit "STOP" you will get a `KeyboardInterrupt` "error"! No worries! :)**

# %% [markdown]
# ## Start evaluating:
# This function evaluates a trained model for a specific shuffle/shuffles at a particular state or all the states on the data set (images)
# and stores the results as .csv file in a subdirectory under **evaluation-results-pytorch**

# %%
deeplabcut.evaluate_network(path_config_file, plotting=True)

# Here you want to see a low pixel error! Of course, it can only be as
# good as the labeler, so be sure your labels are good!
# Out:
# Evaluation scorer: DLC_Resnet50_Testing_deeplabcutFeb23shuffle1_snapshot_best-90
# 100%|██████████| 18/18 [00:00<00:00, 30.75it/s]
# 100%|██████████| 1/1 [00:00<00:00, 67.63it/s]
# Evaluation results file: DLC_Resnet50_Testing_deeplabcutFeb23shuffle1_snapshot_best-90-results.csv
# Evaluation results for DLC_Resnet50_Testing_deeplabcutFeb23shuffle1_snapshot_best-90-results.csv (pcutoff: 0.6):
# train rmse            28.23
# train rmse_pcutoff    19.77
# train mAP             60.83
# train mAR             68.33
# test rmse              8.60
# test rmse_pcutoff      8.73
# test mAP              60.00
# test mAR              60.00
# Name: (0.95, 1, 90, -1, 0.6), dtype: float64

# %% [markdown]
# ## There is an optional refinement step you can do outside of Colab:
# - if your pixel errors are not low enough, please check out the protocol guide on how to refine your network!
# - You will need to adjust the labels **outside of Colab!** We recommend coming back to train and analyze videos...
# - Please see the repo and protocol instructions on how to refine your data!

# %% [markdown]
# ## Start Analyzing videos:
# This function analyzes the new video. The user can choose the best model from the evaluation results and specify the correct snapshot index for the variable **snapshotindex** in the **config.yaml** file. Otherwise, by default the most recent snapshot is used to analyse the video.
#
# The results are stored in hd5 file in the same directory where the video resides.

# %%
deeplabcut.analyze_videos(
    path_config_file,
    videofile_path,
    videotype=video_type,
    destfolder=destfolder,
)
# Out:
# Creating the output folder /content/Testing_deeplabcut-Ahmed-2026-02-23/labeled-videos
# Analyzing videos with /content/Testing_deeplabcut-Ahmed-2026-02-23/dlc-models-pytorch/iteration-0/Testing_deeplabcutFeb23-trainset95shuffle1/train/snapshot-best-090.pt
# Using scorer: DLC_Resnet50_Testing_deeplabcutFeb23shuffle1_snapshot_best-90
# Starting to analyze /content/Testing_deeplabcut-Ahmed-2026-02-23/videos/cat_walking_1.mp4
# Video metadata:
#   Overall # of frames:    1331
#   Duration of video [s]:  44.41
#   fps:                    29.97
#   resolution:             w=640, h=360
#
# Running pose prediction with batch size 8
# 100%|██████████| 1331/1331 [00:39<00:00, 33.93it/s]
# Saving results in /content/Testing_deeplabcut-Ahmed-2026-02-23/labeled-videos/cat_walking_1DLC_Resnet50_Testing_deeplabcutFeb23shuffle1_snapshot_best-90.h5 and /content/Testing_deeplabcut-Ahmed-2026-02-23/labeled-videos/cat_walking_1DLC_Resnet50_Testing_deeplabcutFeb23shuffle1_snapshot_best-90_full.pickle
# The videos are analyzed. Now your research can truly start!
# You can create labeled videos with 'create_labeled_video'.
# If the tracking is not satisfactory for some videos, consider expanding the training set. You can use the function 'extract_outlier_frames' to extract a few representative outlier frames.
# 'DLC_Resnet50_Testing_deeplabcutFeb23shuffle1_snapshot_best-90'

# %% [markdown]
# ## Plot the trajectories of the analyzed videos:
# This function plots the trajectories of all the body parts across the entire video. Each body part is identified by a unique color.

# %%
deeplabcut.plot_trajectories(
    path_config_file,
    videofile_path,
    videotype=video_type,
    destfolder=destfolder,
)

# %% [markdown]
# Now you can look at the plot-poses file and check the "plot-likelihood.png" might want to change the "p-cutoff" in the config.yaml file so that you have only high confidnece points plotted in the video. i.e. ~0.8 or 0.9. The current default is 0.4.

# %% [markdown]
# ## Create labeled video:
# This function is for visualization purpose and can be used to create a video in .mp4 format with labels predicted by the network. This video is saved in the same directory where the original video resides.

# %%
deeplabcut.create_labeled_video(
    path_config_file,
    videofile_path,
    videotype=video_type,
    destfolder=destfolder,
)
# Out:
# Analyzing all the videos in the directory...
# Starting to process video: /content/Testing_deeplabcut-Ahmed-2026-02-23/videos/cat_walking_1.mp4
# Loading /content/Testing_deeplabcut-Ahmed-2026-02-23/videos/cat_walking_1.mp4 and data.
# Duration of video [s]: 44.41, recorded with 29.97 fps!
# Overall # of frames: 1331 with cropped frame dimensions: 640 360
# Generating frames and creating video.
# 100%|██████████| 1331/1331 [00:05<00:00, 262.86it/s]
# [True]
